# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# load csv files into dataframes
jan = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_jan_18521_2024_10_31_15_23_50.csv')
feb = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_feb_18521_2024_10_31_15_23_46.csv')
mar = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_mar_18521_2024_10_31_15_23_41.csv')
apr = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_apr_18521_2024_10_31_15_23_37.csv')
may = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_may_18521_2024_10_31_15_23_34.csv')
jun = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_jun_18521_2024_10_31_15_37_28.csv')
jul = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_jul_18521_2024_10_31_15_23_26.csv')
aug = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_aug_18521_2024_10_31_15_23_21.csv')
sep = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_sep_18521_2024_10_31_15_23_10.csv')
oct = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_oct_18521_2024_11_02_10_38_37.csv')
nov = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_nov_18521_2024_10_31_15_22_53.csv')
dec = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_dec_18521_2024_10_31_14_44_27.csv')

list_of_df = [jan, feb, mar, apr, may, jun, jul, aug, sep, oct, nov, dec]
print(jan)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       3 import matplotlib.pyplot as plt
#       5 # load csv files into dataframes
# ----> 6 jan = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_jan_18521_2024_10_31_15_23_50.csv')
#       7 feb = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_feb_18521_2024_10_31_15_23_46.csv')
#       8 mar = pd.read_csv('../data/USS daily waiting time/download_universal-studios-singapore_mar_18521_2024_10_31_15_23_41.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/USS daily waiting time/download_universal-studios-singapore_jan_18521_2024_10_31_15_23_50.csv'

# %%
# Define the start and end dates for each month in 2024
start_dates = [
    "2024-01-01 00:00:00", "2024-02-01 00:00:00", "2024-03-01 00:00:00",
    "2024-04-01 00:00:00", "2024-05-01 00:00:00", "2024-06-01 00:00:00",
    "2024-07-01 00:00:00", "2024-08-01 00:00:00", "2024-09-01 00:00:00",
    "2023-10-01 00:00:00", "2023-11-01 00:00:00", "2023-12-01 00:00:00"
]

end_dates = [
    "2024-01-31 23:59:59", "2024-02-29 23:59:59", "2024-03-31 23:59:59",
    "2024-04-30 23:59:59", "2024-05-31 23:59:59", "2024-06-30 23:59:59",
    "2024-07-31 23:59:59", "2024-08-31 23:59:59", "2024-09-30 23:59:59",
    "2023-10-31 23:59:59", "2023-11-30 23:59:59", "2023-12-31 23:59:59"
]

month_names = ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]

# Here we will tidying up the df by trimming the days that are not within the time frame intended (1 Nov 2023 - 31 Oct 2024)

filtered_dfs = {}

for df, start_date, end_date, month in zip(list_of_df, start_dates, end_dates, month_names):
    df['Date/Time'] = pd.to_datetime(df['Date/Time']) # Ensure 'Date/Time' is in datetime format
    
    # tidying up the df by trimming the days that are not within the time frame intended
    filtered_df = df[(df['Date/Time'] >= start_date) & (df['Date/Time'] <= end_date)]
    
    filtered_dfs[month] = filtered_df

# %%
# OPTIONAL CELL (TO CHECK OUTPUT)
for month, month_df in filtered_dfs.items():
    print(f"{month}:\n", month_df)
# Out:
# jan:
#                               Park           Date/Time  Wait Time
# 1749  Universal Studios Singapore 2024-01-01 10:00:00          7
# 1750  Universal Studios Singapore 2024-01-01 10:05:00          7
# 1751  Universal Studios Singapore 2024-01-01 10:10:00          7
# 1752  Universal Studios Singapore 2024-01-01 10:15:00          7
# 1753  Universal Studios Singapore 2024-01-01 10:20:00          7
# ...                           ...                 ...        ...
# 4673  Universal Studios Singapore 2024-01-31 19:35:00          8
# 4674  Universal Studios Singapore 2024-01-31 19:40:00          8
# 4     Universal Studios Singapore 2023-10-01 10:20:00          9
# ...                           ...                 ...        ...
# 3318  Universal Studios Singapore 2023-10-31 16:35:00         13
# 3319  Universal Studios Singapore 2023-10-31 16:40:00         12
# 3320  Universal Studios Singapore 2023-10-31 16:45:00         10
# 3321  Universal Studios Singapore 2023-10-31 16:50:00         10
# 3322  Universal Studios Singapore 2023-10-31 16:55:00         12
#
# [3323 rows x 3 columns]
# nov:
#                               Park           Date/Time  Wait Time
# 0     Universal Studios Singapore 2023-11-01 10:00:00          6
# 1     Universal Studios Singapore 2023-11-01 10:05:00          6
# 2     Universal Studios Singapore 2023-11-01 10:10:00          6
# 3     Universal Studios Singapore 2023-11-01 10:15:00          6
# 4     Universal Studios Singapore 2023-11-01 10:20:00          6
# ...                           ...                 ...        ...
# 2147  Universal Studios Singapore 2023-11-30 17:35:00          8
# 2148  Universal Studios Singapore 2023-11-30 17:40:00          8
# 2149  Universal Studios Singapore 2023-11-30 17:45:00          8
# 2150  Universal Studios Singapore 2023-11-30 17:50:00          8
# 2151  Universal Studios Singapore 2023-11-30 17:55:00          8
#
# [2152 rows x 3 columns]
# dec:
#                               Park           Date/Time  Wait Time
# 0     Universal Studios Singapore 2023-12-01 11:05:00          7
# 1     Universal Studios Singapore 2023-12-01 11:10:00          7
# 2     Universal Studios Singapore 2023-12-01 11:15:00          8
# 3     Universal Studios Singapore 2023-12-01 11:20:00         11
# 4     Universal Studios Singapore 2023-12-01 11:25:00         11
# ...                           ...                 ...        ...
# 2603  Universal Studios Singapore 2023-12-31 20:35:00          7
# 2604  Universal Studios Singapore 2023-12-31 20:40:00          7
# 2605  Universal Studios Singapore 2023-12-31 20:45:00          7
# 2606  Universal Studios Singapore 2023-12-31 20:50:00          7
# 2607  Universal Studios Singapore 2023-12-31 20:55:00          7
#
# [2608 rows x 3 columns]

# %%
# Reformatting the datas
for month in filtered_dfs.keys():
    filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
    filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
    filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
    filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
    filtered_dfs[month] = filtered_dfs[month].drop(columns=['Park'], errors='ignore')
# Out:
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Month'] = filtered_dfs[month]['Date/Time'].dt.month
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day'] = filtered_dfs[month]['Date/Time'].dt.day
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Time'] = filtered_dfs[month]['Date/Time'].dt.strftime('%H:%M')
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/4221164102.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dfs[month]['Day of Week'] = filtered_dfs[month]['Date/Time'].dt.day_name()

# %%
# OPTIONAL CELL (TO CHECK OUTPUT)

for month, month_df in filtered_dfs.items():
    print(f"{month}:\n", month_df)
# Out:
# jan:
#                 Date/Time  Wait Time  Month  Day   Time Day of Week
# 1749 2024-01-01 10:00:00          7      1    1  10:00      Monday
# 1750 2024-01-01 10:05:00          7      1    1  10:05      Monday
# 1751 2024-01-01 10:10:00          7      1    1  10:10      Monday
# 1752 2024-01-01 10:15:00          7      1    1  10:15      Monday
# 1753 2024-01-01 10:20:00          7      1    1  10:20      Monday
# ...                  ...        ...    ...  ...    ...         ...
# 4673 2024-01-31 19:35:00          8      1   31  19:35   Wednesday
# 4674 2024-01-31 19:40:00          8      1   31  19:40   Wednesday
# 4675 2024-01-31 19:45:00          8      1   31  19:45   Wednesday
# 4676 2024-01-31 19:50:00          8      1   31  19:50   Wednesday
# 4677 2024-01-31 19:55:00          8      1   31  19:55   Wednesday
#
# [2929 rows x 6 columns]
# feb:
#                 Date/Time  Wait Time  Month  Day   Time Day of Week
#

#                 Date/Time  Wait Time  Month  Day   Time Day of Week
# 0    2023-10-01 10:00:00          6     10    1  10:00      Sunday
# 1    2023-10-01 10:05:00          8     10    1  10:05      Sunday
# 2    2023-10-01 10:10:00          8     10    1  10:10      Sunday
# 3    2023-10-01 10:15:00          9     10    1  10:15      Sunday
# 4    2023-10-01 10:20:00          9     10    1  10:20      Sunday
# ...                  ...        ...    ...  ...    ...         ...
# 3318 2023-10-31 16:35:00         13     10   31  16:35     Tuesday
# 3319 2023-10-31 16:40:00         12     10   31  16:40     Tuesday
# 3320 2023-10-31 16:45:00         10     10   31  16:45     Tuesday
# 3321 2023-10-31 16:50:00         10     10   31  16:50     Tuesday
# 3322 2023-10-31 16:55:00         12     10   31  16:55     Tuesday
#
# [3323 rows x 6 columns]
# nov:
#                 Date/Time  Wait Time  Month  Day   Time Day of Week
# 0    2023-11-01 10:00:00          6     11    1  10:00   Wednesday
# 1    2023-11-01 10:05:00          6     11    1  10:05   Wednesday
# 2    2023-11-01 10:10:00          6     11    1  10:10   Wednesday
# 3    2023-11-01 10:15:00          6     11    1  10:15   Wednesday
# 4    2023-11-01 10:20:00          6     11    1  10:20   Wednesday
# ...                  ...        ...    ...  ...    ...         ...
# 2147 2023-11-30 17:35:00          8     11   30  17:35    Thursday
# 2148 2023-11-30 17:40:00          8     11   30  17:40    Thursday
# 2149 2023-11-30 17:45:00          8     11   30  17:45    Thursday
# 2150 2023-11-30 17:50:00          8     11   30  17:50    Thursday
# 2151 2023-11-30 17:55:00          8     11   30  17:55    Thursday
#
# [2152 rows x 6 columns]
# dec:
#                 Date/Time  Wait Time  Month  Day   Time Day of Week
# 0    2023-12-01 11:05:00          7     12    1  11:05      Friday
# 1    2023-12-01 11:10:00          7     12    1  11:10      Friday
# 2    2023-12-01 11:15:00          8     12    1  11:15      Friday
# 3    2023-12-01 11:20:00         11     12    1  11:20      Friday
# 4    2023-12-01 11:25:00         11     12    1  11:25      Friday
# ...                  ...        ...    ...  ...    ...         ...
# 2603 2023-12-31 20:35:00          7     12   31  20:35      Sunday
# 2604 2023-12-31 20:40:00          7     12   31  20:40      Sunday
# 2605 2023-12-31 20:45:00          7     12   31  20:45      Sunday
# 2606 2023-12-31 20:50:00          7     12   31  20:50      Sunday
# 2607 2023-12-31 20:55:00          7     12   31  20:55      Sunday
#
# [2608 rows x 6 columns]

# %%
# Importing CSV file on holiday information within the time frame intended (1 Nov 2023 - 31 Oct 2024)
# CSV file generated by ChatGPT
holidays_df = pd.read_csv('../data/singapore_holidays_oct2023_sep2024.csv')

# %%
# Setting up filters
school_holidays_mask_1 = holidays_df[(holidays_df['School Holiday'] == 1) & (holidays_df['Public Holiday'] == 0)]
school_holidays_mask_2 = holidays_df[(holidays_df['Public Holiday'] == 1) & (holidays_df['School Holiday'] == 0)]
school_holidays_mask_3 = holidays_df[
    (holidays_df['School Holiday'] == 0) & 
    (holidays_df['Public Holiday'] == 0) & 
    (~holidays_df['Day of the Week'].isin(['Saturday', 'Sunday']))]

school_holidays_mask_4 = holidays_df[
    (holidays_df['School Holiday'] == 0) & 
    (holidays_df['Public Holiday'] == 0) & 
    (holidays_df['Day of the Week'].isin(['Saturday', 'Sunday']))]

school_holidays_mask_5 = holidays_df[(holidays_df['Public Holiday'] == 1) & (holidays_df['School Holiday'] == 1)]

# %%
# Now we create dictionaries with filtered DataFrames for each type of holiday per month

# Initialize dictionaries to store the results
school_holiday_dfs = {}
public_holiday_dfs = {}
weekday_non_holiday_dfs = {}
weekend_non_holiday_dfs = {}
both_holiday_dfs = {}

# Loop through each month in list_of_months
for month in filtered_dfs.keys():
    school_holiday_dfs[month] = filtered_dfs[month][
        filtered_dfs[month][['Month', 'Day']].apply(tuple, axis=1).isin(
            school_holidays_mask_1[['Month', 'Day']].apply(tuple, axis=1)
        )
    ]

    public_holiday_dfs[month] = filtered_dfs[month][
        filtered_dfs[month][['Month', 'Day']].apply(tuple, axis=1).isin(
            school_holidays_mask_2[['Month', 'Day']].apply(tuple, axis=1)
        )
    ]

    weekday_non_holiday_dfs[month] = filtered_dfs[month][
        filtered_dfs[month][['Month', 'Day']].apply(tuple, axis=1).isin(
            school_holidays_mask_3[['Month', 'Day']].apply(tuple, axis=1)
        )
    ]

    weekend_non_holiday_dfs[month] = filtered_dfs[month][
        filtered_dfs[month][['Month', 'Day']].apply(tuple, axis=1).isin(
            school_holidays_mask_4[['Month', 'Day']].apply(tuple, axis=1)
        )
    ]

    both_holiday_dfs[month] = filtered_dfs[month][
        filtered_dfs[month][['Month', 'Day']].apply(tuple, axis=1).isin(
            school_holidays_mask_5[['Month', 'Day']].apply(tuple, axis=1)
        )
    ]

# %%
# OPTIONAL CELL (TO CHECK OUTPUT)
print(both_holiday_dfs.keys())
print(both_holiday_dfs['jun'])
# Out:
# dict_keys(['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
#                Date/Time  Wait Time  Month  Day   Time Day of Week
# 3823 2024-06-17 10:00:00          7      6   17  10:00      Monday
# 3824 2024-06-17 10:05:00         10      6   17  10:05      Monday
# 3825 2024-06-17 10:10:00         10      6   17  10:10      Monday
# 3826 2024-06-17 10:15:00         11      6   17  10:15      Monday
# 3827 2024-06-17 10:20:00         14      6   17  10:20      Monday
# ...                  ...        ...    ...  ...    ...         ...
# 3933 2024-06-17 19:35:00         10      6   17  19:35      Monday
# 3934 2024-06-17 19:40:00          8      6   17  19:40      Monday
# 3935 2024-06-17 19:45:00          8      6   17  19:45      Monday
# 3936 2024-06-17 19:50:00          8      6   17  19:50      Monday
# 3937 2024-06-17 19:55:00          8      6   17  19:55      Monday
#
# [115 rows x 6 columns]

# %%
# Now we use groupby Time to calculate the average wait times in 5 minute intervals

# Initialize dictionaries to store the average wait times
average_wait_times = {
    'school_holiday': {},
    'public_holiday': {},
    'weekday_non_holiday': {},
    'weekend_non_holiday': {},
    'both_holiday': {}
}

# Loop through each dictionary
for holiday_type, dfs in {
    'school_holiday': school_holiday_dfs,
    'public_holiday': public_holiday_dfs,
    'weekday_non_holiday': weekday_non_holiday_dfs,
    'weekend_non_holiday': weekend_non_holiday_dfs,
    'both_holiday': both_holiday_dfs
}.items():
    
    for month, df in dfs.items():
        # Check if the DataFrame is not empty
        if not df.empty:
            # Calculate the average wait time for each time
            avg_wait_time = df.groupby('Time')['Wait Time'].mean().reset_index()
            avg_wait_time.columns = ['Time', 'Average Wait Time']
            
            # Calculate the number of visitors (assuming 5 visitors per minute of wait time)
            avg_wait_time['Number of Visitors'] = (
                avg_wait_time['Average Wait Time'].round() * 5  # Round the wait time and multiply by 5
            )
            # Calculate number of new visitors coming in every 5 minutes
            avg_wait_time['Number of New Visitors Arriving'] = (
                avg_wait_time['Number of Visitors']
                - avg_wait_time['Number of Visitors'].shift(1)
            ) * 10 ##### IMP: use a random number 10, need to be replaced by the total number of rides (from graph.py)
            # To fill the NaN value in the first row with the initial value
            avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
                avg_wait_time['Number of Visitors'].iloc[0]
            )

            # Store the result in the dictionary
            average_wait_times[holiday_type][month] = avg_wait_time
# Out:
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (
# /var/folders/s3/x_gq7dtj25z5d_3nmhjk3d340000gn/T/ipykernel_39692/3185235786.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_wait_time['Number of New Visitors Arriving'].iloc[0] = (

# %%
# OPTIONAL CELL (TO CHECK OUTPUT)
print(average_wait_times['school_holiday']['jun'])
print(average_wait_times['weekend_non_holiday']['apr'])
# Out:
#       Time  Average Wait Time  Number of Visitors  \
# 0    10:00           7.350000                35.0
# 1    10:05           7.600000                40.0
# 2    10:10           9.000000                45.0
# 3    10:15           9.619048                50.0
# 4    10:20          10.500000                50.0
# ..     ...                ...                 ...
# 151  22:35          18.000000                90.0
# 152  22:40          18.000000                90.0
# 153  22:45          16.000000                80.0
# 154  22:50          16.000000                80.0
# 155  22:55          16.000000                80.0
#
#      Number of New Visitors Arriving
# 0                               35.0
# 1                               50.0
# 2                               50.0
# 3                               50.0
# 4                                0.0
# ..                               ...
# 151                            -50.0
# 152                              0.0
# 153                           -100.0
# 154                              0.0
# 155                              0.0
#
# [156 rows x 4 columns]
#       Time  Average Wait Time  Number of Visitors  \
# 0    10:00           7.125000                35.0
# 1    10:05           7.125000                35.0
# 2    10:10           7.250000                35.0
# 3    10:15           7.714286                40.0
# 4    10:20           8.000000                40.0
# ..     ...                ...                 ...
# 115  19:35           8.250000                40.0
# 116  19:40           8.000000                40.0
# 117  19:45           7.600000                40.0
# 118  19:50           7.600000                40.0
# 119  19:55           7.600000                40.0
#
#      Number of New Visitors Arriving
# 0                               35.0
# 1                                0.0
# 2                                0.0
# 3                               50.0
# 4                                0.0
# ..                               ...
# 115                              0.0
# 116                              0.0
# 117                              0.0
# 118                              0.0
# 119                              0.0
#
# [120 rows x 4 columns]

# %%
print(average_wait_times['weekend_non_holiday']['apr'])
# Out:
#       Time  Average Wait Time  Number of Visitors  \
# 0    10:00           7.125000                35.0
# 1    10:05           7.125000                35.0
# 2    10:10           7.250000                35.0
# 3    10:15           7.714286                40.0
# 4    10:20           8.000000                40.0
# ..     ...                ...                 ...
# 115  19:35           8.250000                40.0
# 116  19:40           8.000000                40.0
# 117  19:45           7.600000                40.0
# 118  19:50           7.600000                40.0
# 119  19:55           7.600000                40.0
#
#      Number of New Visitors Arriving
# 0                               35.0
# 1                                0.0
# 2                                0.0
# 3                               50.0
# 4                                0.0
# ..                               ...
# 115                              0.0
# 116                              0.0
# 117                              0.0
# 118                              0.0
# 119                              0.0
#
# [120 rows x 4 columns]

# %% [markdown]
# We assume that there is a relation between waiting time and number of visitors coming into the park
# We estimate 1 minute of waiting time equals to 5 visitors.
# Another assumption is 20% of visitors purchase fast-pass tickets.

# %%
# Export DataFrame to CSV file
# Example: we want weekend_non_holiday in April

df = average_wait_times['weekend_non_holiday']['apr'] # get the df from the dictionary

df.to_csv('../data/spawning.csv', index=False)  # index=False to avoid writing row numbers
